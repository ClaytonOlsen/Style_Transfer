# %%
import matplotlib.pyplot as plt
from utility_functions.preprocessing_utility import *
from utility_functions.style_transfer_models import *
tf.config.run_functions_eagerly(True)

# %%
#Content Image
content_path = tf.keras.utils.get_file('belfry.jpg','https://storage.googleapis.com/khanhlvg-public.appspot.com/arbitrary-style-transfer/belfry-2611573_1280.jpg')
#Style Image
#style_path = tf.keras.utils.get_file("starry_night.jpg", "https://i.imgur.com/9ooB60I.jpg")
style_path = "/Users/clayolsen1/ML_folder/Style_transfering_NN/style_images/8bit.jpg"
#style_path = "/Users/clayolsen1/ML_folder/Style_transfering_NN/style_images/stardew.jpg"

content_image = load_img(content_path)
style_image = load_img(style_path)
style_image = tf.nn.avg_pool(style_image, ksize = [3,3], strides = [1,1], padding = 'SAME')

#imshow(content_image)
imshow(style_image)

# %%
imshow(content_image)

# %%
image, total_loss = image_style_transfer(content_path, style_path, epochs = 1000)
# Out:
# Current Loss: [9681033.]
# Step: 900
# <PIL.Image.Image image mode=RGB size=512x339 at 0x14C544A90>

# %%
tensor_to_image(image)
# Out:
# <PIL.Image.Image image mode=RGB size=512x339 at 0x14C523970>

# %%
plt.plot(total_loss[800:])
